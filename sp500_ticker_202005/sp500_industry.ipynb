# %% [markdown]
# ## S&P 500 company distributioin by industry

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read data from github
# **github data url**
# https://github.com/datasets
# https://github.com/datasets/s-and-p-500-companies/tree/master/data
# https://github.com/datasets/s-and-p-500-companies/raw/master/data/constituents.csv
# **convert to raw data url**
# https://raw.github.com/datasets/s-and-p-500-companies/master/data/constituents.csv

# %%
url = 'https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv'

# %%
sp500 = pd.read_csv(url)

# %%
sp500.head()
# Out:
#   Symbol                 Name       Sector
# 0    MMM           3M Company  Industrials
# 1    AOS      A.O. Smith Corp  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV          AbbVie Inc.  Health Care
# 4   ABMD          ABIOMED Inc  Health Care

# %%
tick_cnt = sp500.groupby('Sector')['Symbol'].count()

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n{:d}".format(pct, absolute)

# %% [markdown]
# ### Pie Chart

# %%
plt.pie(tick_cnt, radius = 2, labels = tick_cnt.index, autopct=lambda pct: func(pct, tick_cnt.values))
plt.show()

# %% [markdown]
# ### Donut Chart

# %%
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.6, color='white')
plt.pie(tick_cnt, radius = 2, labels = tick_cnt.index, autopct=lambda pct: func(pct, tick_cnt.values))
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
